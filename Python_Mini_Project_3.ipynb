# %% [markdown]
# <a href="https://colab.research.google.com/github/mskalaiwani00294-lang/Python-Mini-Projects/blob/main/Python_Mini_Project_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# List Methods and Slicing
#
# Project Title: Contact Directory
#
# Scenario:
#
#  You have been assigned to build a contact management system where employees can store and retrieve contact details efficiently.
#
# Tasks:
#
# Create a 2D list where each row holds a contact’s name, phone number, and email address.
#
# Allow the user to add a new contact.
#
# Remove the last item
#
# Get new items from the users using input() and add those items to the list
#
#  Sort the list in ascending order based on any values

# %% [markdown]
# # **Contact Directory**

# %%
#Create  2d list
contacts=[["Arun", "9876543210", "arun@gmail.com"],
    ["Bala", "9876501234", "bala@gmail.com"],
    ["Cady", "9876512345", "cady@gmail.com"]
]

# %%
#Allow the user to add a new contact
name=input("Enter Name:")
Number=input("Enter Contact Number:")
Email=input("Enter Email:")
# Out:
# Enter Name:veera
# Enter Contact Number:9077744400
# Enter Email:veera0122@gamil.com

# %%
#add new contact
contacts.append([name,Number,Email])
print("\n After Removing Last Contact:",contacts)
# Out:
#  After Removing Last Contact: [['Arun', '9876543210', 'arun@gmail.com'], ['Bala', '9876501234', 'bala@gmail.com'], ['Cady', '9876512345', 'cady@gmail.com'], ['veera', '9077744400', 'veera0122@gamil.com']]

# %%
#Remove the last item
contacts.pop()
# Out:
# ['veera', '9077744400', 'veera0122@gamil.com']

# %%
#Get new items from the users using input() and add those items to the list
name=input("Enter Name:")
Number=input("Enter Contact Number:")
Email=input("Enter Email:")
# Out:
# Enter Name:Zara Rathi
# Enter Contact Number:7689344509
# Enter Email:zararathi08@gmail.com

# %%
contacts.append([name,Number,Email])
print("\n After Removing Last Contact:",contacts)
# Out:
#  After Removing Last Contact: [['Arun', '9876543210', 'arun@gmail.com'], ['Bala', '9876501234', 'bala@gmail.com'], ['Cady', '9876512345', 'cady@gmail.com'], ['Zara Rathi', '7689344509', 'zararathi08@gmail.com']]

# %%
#Sort the list in ascending order based on any values
contacts.sort()

print("\n Sorted Contact:",contacts)
# Out:
#  Sorted Contact: [['Arun', '9876543210', 'arun@gmail.com'], ['Bala', '9876501234', 'bala@gmail.com'], ['Cady', '9876512345', 'cady@gmail.com'], ['Zara Rathi', '7689344509', 'zararathi08@gmail.com']]

# %%
#display contacts
print(" Contacts,\n,:",contacts)
# Out:
#  Contacts,
# ,: [['Arun', '9876543210', 'arun@gmail.com'], ['Bala', '9876501234', 'bala@gmail.com'], ['Cady', '9876512345', 'cady@gmail.com'], ['Zara Rathi', '7689344509', 'zararathi08@gmail.com']]
