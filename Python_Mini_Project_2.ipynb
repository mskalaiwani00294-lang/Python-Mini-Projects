# %% [markdown]
# <a href="https://colab.research.google.com/github/mskalaiwani00294-lang/Python-Mini-Projects/blob/main/Python_Mini_Project_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 🏫 Student Management & Academic Record System
#
# 🎯 Objective:
#
# Understand how to use Tuples (immutable data) and Lists (mutable, structured data) together
# to manage and organize information efficiently.
#
# 🧩 Scenario:
#
# • A school wants to maintain student data and marks for analysis.
#
# • Each student’s personal details are fixed (Name, Roll Number, Course) → stored in a Tuple.
#
# • Each student’s subject marks are modifiable → stored in a List.
#
# • A collection of all students’ marks is stored as a 2D List.
#
#
# • For advanced organization, a 3D List is used to represent marks for multiple batches.

# %% [markdown]
#  **Student Management & Academic Record System :**

# %%
# Step 1: Create Tuple for each student
student1 = ("Kalai", 101, "English")
student2 = ("Kathir", 102, "Maths")
student3 = ("Lattu", 103, "Tamil")

# Step 2: Create 1D List for marks of each student
marks1 = [85, 90, 78]
marks2 = [75, 88, 92]
marks3 = [80, 85, 89]

print("Student 1:", student1)
print("Marks:", marks1)

print("Student 2:", student2)
print("Marks:", marks2)

print("Student 3:", student3)
print("Marks:", marks3)

# Step 3: Combine all marks into a 2D List
batch1 = [marks1, marks2, marks3]

print("\nBatch 1 Marks:")
print(batch1)
# Out:
# Student 1: ('Kalai', 101, 'English')
# Marks: [85, 90, 78]
# Student 2: ('Kathir', 102, 'Maths')
# Marks: [75, 88, 92]
# Student 3: ('Lattu', 103, 'Tamil')
# Marks: [80, 85, 89]
#
# Batch 1 Marks:
# [[85, 90, 78], [75, 88, 92], [80, 85, 89]]
