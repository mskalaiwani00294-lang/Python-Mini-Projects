# %% [markdown]
# <a href="https://colab.research.google.com/github/mskalaiwani00294-lang/Python-Mini-Projects/blob/main/Python_Mini_Project_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  **Student Management & Academic Record System :**

# %%
#Step 1: Create Tuple for each student (immutable personal info)
Student1="Kalai",101,"Enlish"
Student2="kathir",102,"Maths"
Student3="Lattu",103,"Tamil"

print("Student tuples")
print("Stundent1")
print("Stundent2")
print("Stundent3")
# Out:
# Student tuples
# Stundent1
# Stundent2
# Stundent3

# %%
# Step 2: Create 1D List for marks for 3 students
Subjects=("Enlish","Maths","Tamil")
marks1=(85,90,88)
marks2=(78,82,80)
marks3=(92,89,95)
print("Subjects:",Subjects)
print("\nstep2 1Dl list of marks")
print("Student 1 marks:",marks1)
print("Student 2 marks:",marks2)
print("Student 3 marks:",marks3)
# Out:
# Subjects: ('Enlish', 'Maths', 'Tamil')
#
# step2 1Dl list of marks
# Student 1 marks: (85, 90, 88)
# Student 2 marks: (78, 82, 80)
# Student 3 marks: (92, 89, 95)

# %%
# Step 3: Combine all marks into a 2D List
batch1=(marks1,marks2,marks3)
print("\nstep3 2D list")
print("batch1")
# Out:
# step3 2D list
# batch1

# %%
# create another 2d called batch2 and store 3 more students marks
Student4="Riya,104,English"
Student5="Tittu,105,Maths,"
Student6="Tigar,106,Tamil"
marks4=(88,91,85)
marks5=(76,84,90)
marks6=(95,92,80)
batch2=(marks4,marks5,marks6)
all_batch=(batch1,batch2)

print("\n 3D list-Multiple Batches")
print("Batch 1:",batch1)
print("Batch 2:",batch2)
print("All Batches:",all_batch)
# Out:
#  3D list-Multiple Batches
# Batch 1: ((85, 90, 88), (78, 82, 80), (92, 89, 95))
# Batch 2: ((88, 91, 85), (76, 84, 90), (95, 92, 80))
# All Batches: (((85, 90, 88), (78, 82, 80), (92, 89, 95)), ((88, 91, 85), (76, 84, 90), (95, 92, 80)))

# %%
#Step 5: Display formatted data)
print("\n Formatting Data")
print("\n Batch 1")
print("Kalai,Roll No:101-Marks:",marks1)
print("kathir,Roll No:102-Marks:",marks2)
print("Lattu,Roll No:103-Marks:",marks3)
print("\nBatch 2")
print("Riya,Roll No:104-Marks:",marks4)
print("Tittu,Roll No:105-Marks:",marks5)
print("Tigar,Roll No:106-Marks:",marks6)
# Out:
#  Formatting Data
#
#  Batch 1
# Kalai,Roll No:101-Marks: (85, 90, 88)
# kathir,Roll No:102-Marks: (78, 82, 80)
# Lattu,Roll No:103-Marks: (92, 89, 95)
#
# Batch 2
# Riya,Roll No:104-Marks: (88, 91, 85)
# Tittu,Roll No:105-Marks: (76, 84, 90)
# Tigar,Roll No:106-Marks: (95, 92, 80)
