# %% [markdown]
# <a href="https://colab.research.google.com/github/mskalaiwani00294-lang/Python-Mini-Projects/blob/main/Python_Mini__Project_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Project Title: Retail Inventory Manager
#
# Scenario:
#  You are managing an inventory system for a retail shop. Certain product categories are fixed, but the actual products can be added or removed by the staff.

# %% [markdown]
# Tasks:
# * Create a tuple with fixed product categories like Electronics, Stationery, and Clothing.
# * Create a list of products that can be updated dynamically.
# * Ask the user to enter a new product and add it to the list.
# * Ask the user to input the index of a product to remove it from the list.
# * Display the final list of products and the product categories.

# %% [markdown]
# # **Retail Inventory Manager**

# %%
#Create a tuple with fixed product categories like Electronics, Stationery, and Clothing.
#fixed product categories
Categories=("Electronics", "Stationery","Clothing")

# %%
#Create a list of products that can be updated dynamically
Products=["Laptop","Pen","Shirt"]

# %%
#Ask the user to enter a new product and add it to the list.
#add New product
new_product=input("Enter new product:")
Products.append(new_product)
# Out:
# Enter new product:Book

# %%
#Ask the user to input the index of a product to remove it from the list.
index=int(input("enter index to remove:"))
Products.pop(index)
# Out:
# enter index to remove:1
# 'Pen'

# %%
#Display the final list of products and the product categories
#Disply final result
print("Final Products:",Products)
print("Product Categories:",categories)
# Out:
# Final Products: ['Laptop', 'Shirt', 'Book']
# Product Categories: ('Electronics', 'Stationery', 'Clothing')
