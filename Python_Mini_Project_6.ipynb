# %% [markdown]
# <a href="https://colab.research.google.com/github/mskalaiwani00294-lang/Python-Mini-Projects/blob/main/Python_Mini_Project_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Write a program to search for a number in a list using while and break. search for a number in the list using while loop when number is found break the loop

# %%
numbers = [10, 20, 30, 40, 50]

search_number = int(input("Enter a number to search: "))

i = 0

while i < len(numbers):
    if numbers[i] == search_number:
        print("Number found:", search_number)
        break
    i += 1
else:
    print("Number not found")
# Out:
# Enter a number to search: 40
# Number found: 40
